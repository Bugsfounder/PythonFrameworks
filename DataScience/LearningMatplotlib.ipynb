# %%
# %matplotlib inline  
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[4,5,4])
plt.show()

# %%
plt.plot([1,2,6],[4,1,4])
plt.title("Basic Chart")
plt.ylabel("Y LEVEL")
plt.xlabel("X LEVEL")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

# %%
style.use("ggplot")
# style.use("grayscale")
# style.use("seaborn")

# %%
x = [1,5,4]
y = [23,45,88]

# %%
x2 = [2,7,8]
y2 = [8,2,4]

# %%
# plt.plot(x,y, label="First", linewidth=4) # Ploting x,y
# plt.scatter(x,y, label="First", linewidth=4) # Ploting x,y
plt.hist(x, label="First", linewidth=4) # Ploting x,y
plt.plot(x2,y2, label="Second") #ploting x2,y2
plt.legend()
plt.show()

# %%
# plt.style.available # all Styles in matplotlib
